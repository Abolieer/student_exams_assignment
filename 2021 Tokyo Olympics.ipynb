# %% [markdown]
# ## Introduction
#
# To know which factor may affect the student's performance, we classify the score into couple of ranks, and figure out which feature affects the score more significant. The independent variables are follow:
#
# 1. gender : sex of students
# 2. race/ethnicity : ethnicity of students
# 3. parental level of education : parents' final education
# 4. lunch : having lunch before test (normal or abnormal)
# 5. test preparation course : complete or not complete before test

# %%
# %pip install seaborn
import seaborn as sns
import matplotlib.pyplot as plt 
import os 
import pandas as pd 
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.cluster import KMeans
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_111/1371983698.py in <module>
#       5 import pandas as pd
#       6 import numpy as np
# ----> 7 from sklearn.preprocessing import LabelEncoder
#       8 from sklearn.cluster import KMeans
#
# ModuleNotFoundError: No module named 'sklearn'

# %% [markdown]
# Let's see how many datasets in this topic.

# %%
os.listdir(".")
# Out:
# ['.profile',
#  '.bashrc',
#  '.bash_logout',
#  '.local',
#  '.jupyter',
#  '.jupyter-server-log.txt',
#  '.cache',
#  '2021.ipynb',
#  '.ipython',
#  '.config',
#  '2021 (1).ipynb',
#  '.ipynb_checkpoints',
#  'exam_results.csv',
#  'student_exams_assignment (1) (1).ipynb',
#  'student_exams_assignment (1).ipynb',
#  'matplotlib_examples.ipynb',
#  'README.md',
#  'reactors.csv',
#  '.git',
#  'student_exams_assignment.ipynb',
#  '2021.csv',
#  'reactors.ipynb']

# %% [markdown]
# Only one! Take a look at the dataset.

# %%
filename = "2021.csv"
score_df = pd.read_csv(filename, encoding='latin-1')
score_df.head()
# Out:
#                       Country  Gold Medal  Silver Medal  Bronze Medal  Total  \
# 0    United States of America          39            41            33    113
# 1  People's Republic of China          38            32            18     88
# 2                       Japan          27            14            17     58
# 3               Great Britain          22            21            22     65
# 4                         ROC          20            28            23     71
#
#    Rank By Total
# 0              1
# 1              2
# 2              5
# 3              4
# 4              3

# %% [markdown]
# Some column names are too long, rename the column names to be simpler.

# %%
score_df.rename(columns={"Country":"Country","Gold Medal":"Gold"
                    ,"Silver Medal":"Silver","Bronze Medal":"Bronze","Total":"Total",
                    "Rank By Total":"Rank"},inplace=True)
score_df.head()
# Out:
#                       Country  Gold  Silver  Bronze  Total  Rank
# 0    United States of America    39      41      33    113     1
# 1  People's Republic of China    38      32      18     88     2
# 2                       Japan    27      14      17     58     5
# 3               Great Britain    22      21      22     65     4
# 4                         ROC    20      28      23     71     3

# %% [markdown]
# Seems clearly. Check the data type.

# %%
score_df.dtypes
# Out:
# Country    object
# Gold        int64
# Silver      int64
# Bronze      int64
# Total       int64
# Rank        int64
# dtype: object

# %% [markdown]
# Plotting the average scores per gender. Use a Matplotlib Barplot

# %%
total_results = pd.read_csv('2021.csv', encoding='latin-1')
sns.set(rc={'figure.figsize':(5,7)})
sns.barplot(x = 'Total', y = 'Country',data = total_results, ci = None,order=total_results.sort_values('Total',ascending = False).Country)
plt.ylim(-1, 15)
# Out:
# (-1.0, 15.0)

# %% [markdown]
# Plot the average scores per category of "lunch" and "pre". Use a seaborn boxplot chart.

# %%
Gold_results = pd.read_csv('2021.csv', encoding='latin-1')
sns.set(rc={'figure.figsize':(5,7)})
sns.barplot(x = 'Gold Medal', y = 'Country',data = Gold_results, ci = None,order=Gold_results.sort_values('Gold Medal',ascending = False).Country)
plt.ylim(-1, 15)
# Out:
# (0.0, 10.0)

# %%
silver_results = pd.read_csv('2021.csv', encoding='latin-1')
sns.set(rc={'figure.figsize':(5,7)})
sns.barplot(x = 'Silver Medal', y = 'Country',data = silver_results, ci = None,order=silver_results.sort_values('Silver Medal',ascending = False).Country)
plt.ylim(-1, 15)
# Out:
# (0.0, 10.0)

# %%
Bronze_results = pd.read_csv('2021.csv', encoding='latin-1')
sns.set(rc={'figure.figsize':(5,7)})
sns.barplot(x = 'Bronze Medal', y = 'Country',data = Bronze_results, ci = None,order=Bronze_results.sort_values('Bronze Medal',ascending = False).Country)
plt.ylim(-1, 15)
# Out:
# (0.0, 10.0)
